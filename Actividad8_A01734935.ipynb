# %%
import json 
import pandas as pd
import numpy as np
import glob
import LibreriaEduardo as Edu

# %%
df_csv= Edu.cargar_dataset('listings.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_csv= Edu.cargar_dataset('listings.csv')
#
# File c:\Users\USUARIO\Downloads\curso python_Rigo\Tareas\LibreriaEduardo.py:11, in cargar_dataset(archivo)
#       9 # Cargar el archivo según su extensión
#      10     if extension == '.csv':
# ---> 11         df= pd.read_csv(archivo)
#      12         return (df)
#      13     elif extension == '.xlsx':
#
# ...

# %%
df_xlsx=Edu.cargar_dataset('Antigüedad de saldos 17.03.2023.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_xlsx=Edu.cargar_dataset('Antigüedad de saldos 17.03.2023.xlsx')
#
# File c:\Users\USUARIO\Downloads\curso python_Rigo\Tareas\LibreriaEduardo.py:14, in cargar_dataset(archivo)
#      12     return (df)
#      13 elif extension == '.xlsx':
# ---> 14     df= pd.read_excel(archivo)
#      15     return (df)
#      16 elif extension == '.json':
#
# File c:\Users\USUARIO\anaconda3\envs\Analitica\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
# ...

# %%
df_json=Edu.cargar_dataset('data-nl-2015.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_json=Edu.cargar_dataset('data-nl-2015.json')
#
# File c:\Users\USUARIO\Downloads\curso python_Rigo\Tareas\LibreriaEduardo.py:17, in cargar_dataset(archivo)
#      15     return (df)
#      16 elif extension == '.json':
# ---> 17     df= pd.read_json(archivo)
#      18     return (df)
#      19 elif extension == '.html':
#
# File c:\Users\USUARIO\anaconda3\envs\Analitica\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
# ...

# %%
df_html=Edu.cargar_dataset('Data_Airbnb.html')

# %% [markdown]
# ***Funcion de Limpieza***

# %%
df_csv.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               2964
# Length: 79, dtype: int64

# %%
#La columna license no cuenta con un valor distinto a NaN, por lo tanto, forward fill no rellena el valor nulo de la columna y se rellena con un valor específico.
df_fill= Edu.nulos_ffill_df(df_csv)
df_fill
# Out:
# c:\Users\USUARIO\Downloads\Carga de datos\LibreriaEduardo.py:29: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill")
#                         id                                       listing_url  \
# 0                    31094                https://www.airbnb.com/rooms/31094
# 1                    32379                https://www.airbnb.com/rooms/32379
# 2                    32841                https://www.airbnb.com/rooms/32841
# 3                    38499                https://www.airbnb.com/rooms/38499
# 4                    39055                https://www.airbnb.com/rooms/39055
# ...                    ...                                               ...
# 21717  1381033853978414915  https://www.airbnb.com/rooms/1381033853978414915
# 21718  1381049975985409861  https://www.airbnb.com/rooms/1381049975985409861
# ...

# %%
#La columna license no cuenta con un valor distinto a NaN, por lo tanto, backward fill no rellena el valor nulo de la columna y se rellena con un valor específico.
df_bfill= Edu.nulos_bfill_df(df_csv)
df_bfill
# Out:
# c:\Users\USUARIO\Downloads\Carga de datos\LibreriaEduardo.py:37: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="bfill")
#                         id                                       listing_url  \
# 0                    31094                https://www.airbnb.com/rooms/31094
# 1                    32379                https://www.airbnb.com/rooms/32379
# 2                    32841                https://www.airbnb.com/rooms/32841
# 3                    38499                https://www.airbnb.com/rooms/38499
# 4                    39055                https://www.airbnb.com/rooms/39055
# ...                    ...                                               ...
# 21717  1381033853978414915  https://www.airbnb.com/rooms/1381033853978414915
# 21718  1381049975985409861  https://www.airbnb.com/rooms/1381049975985409861
# ...

# %%
df_string= Edu.nulos_string_df(df_csv)
df_string
# Out:
#                         id       scrape_id    host_id  host_listings_count  \
# 0                    31094  20250323161241     129976                  1.0
# 1                    32379  20250323161241     140105                  3.0
# 2                    32841  20250323161241     142143                  1.0
# 3                    38499  20250323161241     122489                  1.0
# 4                    39055  20250323161241     167511                  1.0
# ...                    ...             ...        ...                  ...
# 21717  1381033853978414915  20250323161241  593936121                  1.0
# 21718  1381049975985409861  20250323161241  158835175                  1.0
# 21719  1381084229014752014  20250323161241  187610263                219.0
# 21720  1381103512933847407  20250323161241  187610263                219.0
# 21721  1381626650495736728  20250323161241  320890943                  1.0
#
# ...

# %%
df_limpio= Edu.nulos_prom_df(df_csv)
df_limpio
# Out:
#                         id       scrape_id    host_id  host_listings_count  \
# 0                    31094  20250323161241     129976                  1.0
# 1                    32379  20250323161241     140105                  3.0
# 2                    32841  20250323161241     142143                  1.0
# 3                    38499  20250323161241     122489                  1.0
# 4                    39055  20250323161241     167511                  1.0
# ...                    ...             ...        ...                  ...
# 21717  1381033853978414915  20250323161241  593936121                  1.0
# 21718  1381049975985409861  20250323161241  158835175                  1.0
# 21719  1381084229014752014  20250323161241  187610263                219.0
# 21720  1381103512933847407  20250323161241  187610263                219.0
# 21721  1381626650495736728  20250323161241  320890943                  1.0
#
# ...

# %%
df_mediana= Edu.nulos_mediana_df(df_csv)
df_mediana
# Out:
#                         id       scrape_id    host_id  host_listings_count  \
# 0                    31094  20250323161241     129976                  1.0
# 1                    32379  20250323161241     140105                  3.0
# 2                    32841  20250323161241     142143                  1.0
# 3                    38499  20250323161241     122489                  1.0
# 4                    39055  20250323161241     167511                  1.0
# ...                    ...             ...        ...                  ...
# 21717  1381033853978414915  20250323161241  593936121                  1.0
# 21718  1381049975985409861  20250323161241  158835175                  1.0
# 21719  1381084229014752014  20250323161241  187610263                219.0
# 21720  1381103512933847407  20250323161241  187610263                219.0
# 21721  1381626650495736728  20250323161241  320890943                  1.0
#
# ...

# %%
df_constante= Edu.nulos_constante_df(df_csv)
df_constante
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_constante= Edu.nulos_constante_df(df_csv)
#       2 df_constante
#
# NameError: name 'df_csv' is not defined

# %%
df_identificar= Edu.identificar_nulos_df(df_csv)
df_identificar
